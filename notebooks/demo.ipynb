# %%
import jax
import jax.numpy as np
import flax.linen as nn
import optax

from typing import Sequence, Callable
from functools import partial
import tensorflow_probability.substrates.jax as tfp
from tqdm import trange

tfd = tfp.distributions

# %%
import diffrax as dfx

class MLP(nn.Module):
    """A simple MLP (fully-connected neural network)."""

    feature_sizes: Sequence[int]
    activation: Callable[[np.ndarray], np.ndarray] = nn.gelu

    @nn.compact
    def __call__(self, x, t):
        x = np.concatenate([x, t], axis=-1)
        for features in self.feature_sizes[:-1]:
            x = nn.Dense(features)(x)
            x = self.activation(x)
        x = nn.Dense(self.feature_sizes[-1])(x)
        return x


class SymplecticFlow(nn.Module):

    def setup(self):
        
        self.n_leapfrog_steps = 10
        self.T = 2.0
        self.dt = self.T / self.n_leapfrog_steps
        self.potential_func = MLP([128, 128, 1])
        self.n_dim = 2

    # def leapfrog_step(self, pos, vel, potential_func, dt):
    #     """
    #     Implements a single step of the leapfrog integration method.

    #     Args:
    #         pos (jax.numpy.ndarray): Array of particle positions. Should be in a length unit.
    #         vel (jax.numpy.ndarray): Array of particle velocities.
    #         potential_func (function): Function that computes the potential energy of the system.
    #         dt (float): Time step size.

    #     Returns:
    #         Tuple containing the new positions and velocities, and the Jacobian of the transformation.
    #     """

    #     # Compute the gradient of the potential energy function
    #     grad_potential = jax.grad(potential_func)

    #     # Compute the forces on the particles by evaluating the gradient of the potential energy
    #     vel_dot = -grad_potential(pos)

    #     # Update the velocities by half a time step
    #     vel_half = vel + vel_dot * (dt / 2.0)

    #     # Update the positions using the new velocities
    #     pos_new = pos + vel_half * dt

    #     # Compute the forces on the new positions
    #     forces_new = -grad_potential(pos_new)

    #     # Update the velocities using the new forces
    #     vel_new = vel_half + forces_new * (dt / 2.0)

    #     # Return the new positions and velocities, and the updated Jacobian derivatives as a tuple
    #     return pos_new, vel_new
    
    def leapfrog_step(self, pos, vel, potential_func, dt):

        grad_potential = jax.grad(potential_func)

        w1 = 1 / (2 - 2**(1/3))
        w0 = -(2**(1/3)) * w1
        w = [w1, w0, w1]
        
        for wi in w:
            vel = vel - wi * dt * grad_potential(pos) / 2
            pos = pos + wi * dt * vel
            vel = vel - wi * dt * grad_potential(pos) / 2
        
        return pos, vel

    def dxdt(self, t, v, args):
        return v

    def dvdt(self, t, x, args):
        t = np.ones_like(x)
        potential = lambda x: self.potential_func(x, np.atleast_1d(t))[0]
        grad_potential = jax.grad(potential)
        return -grad_potential(x)

    # def log_prob(self, xv):

    #     pos, vel = np.split(xv, 2, axis=-1)

    #     # Backward leapfrog integration
    #     for i in range(self.n_leapfrog_steps):
    #         pos, vel = self.leapfrog_step(pos, vel, lambda x: self.potential_func(x, np.atleast_1d(self.T - i * self.dt))[0], -self.dt)

    #     # Base distribution is just a standard normal
    #     # We don't need to worry about det-Jacobian because it's unity for leapfrog
    #     base_dist = tfd.MultivariateNormalDiag(loc=np.zeros_like(xv), scale_diag=np.ones_like(xv))

    #     # Compute log-density
    #     log_prob = base_dist.log_prob(np.concatenate([pos, vel], axis=-1))

    #     return log_prob
    
    def log_prob(self, xv):

        # Base distribution is just a standard normal
        base_dist = tfd.MultivariateNormalDiag(loc=np.zeros_like(xv), scale_diag=np.ones_like(xv))

        pos, vel = np.split(xv, 2, axis=-1)
        solver = dfx.LeapfrogMidpoint()

        y0 = np.array([pos, vel])

        terms = dfx.MultiTerm(dfx.ODETerm(self.dxdt), dfx.ODETerm(self.dvdt))
        
        sol = dfx.diffeqsolve(terms, solver, 0.0, self.T, -self.dt, y0=y0)
        (xv,), (delta_log_likelihood,) = sol.ys

        # Compute log-density
        log_prob = base_dist.log_prob(xv) + delta_log_likelihood

        return log_prob

    def sample_single(self, key):

        key, subkey = jax.random.split(key)
        xv = jax.random.normal(subkey, shape=(self.n_dim,))
        pos, vel = np.split(xv, 2, axis=-1)
        
        # Forward leapfrog integration
        for i in range(self.n_leapfrog_steps):
            pos, vel = self.leapfrog_step(pos, vel, lambda x: self.potential_func(x, np.atleast_1d(i * self.dt))[0], self.dt)

        return np.concatenate([pos, vel], axis=-1)

    def sample(self, key, n_samples):
        sample_key = jax.random.split(key, n_samples ** 2)
        return jax.vmap(self.sample_single)(sample_key)
    
    def __call__(self, x):
        return jax.vmap(self.log_prob)(x)

# %%
flow = SymplecticFlow()
xv = jax.random.normal(jax.random.PRNGKey(0), (100, 2))

rng = jax.random.PRNGKey(0)
log_prob, params = flow.init_with_output(rng, xv)
# Out:
# ---------------------------------------------------------------------------
# JaxTransformError                         Traceback (most recent call last)
# /Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb Cell 3 in 5
#       <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> xv = jax.random.normal(jax.random.PRNGKey(0), (100, 2))
#       <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> rng = jax.random.PRNGKey(0)
# ----> <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> log_prob, params = flow.init_with_output(rng, xv)
#
#     [... skipping hidden 7 frame]
#
# /Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb Cell 3 in 1
#     <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=140'>141</a> def __call__(self, x):
# --> <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=141'>142</a>     return jax.vmap(self.log_prob)(x)
#
#     [... skipping hidden 5 frame]
#
# /Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb Cell 3 in 1
#     <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=112'>113</a> y0 = np.array([pos, vel])
#     <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=114'>115</a> terms = dfx.MultiTerm(dfx.ODETerm(self.dxdt), dfx.ODETerm(self.dvdt))
# --> <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=116'>117</a> sol = dfx.diffeqsolve(terms, solver, 0.0, self.T, -self.dt, y0=y0)
#     <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=117'>118</a> (xv,), (delta_log_likelihood,) = sol.ys
#     <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=119'>120</a> # Compute log-density
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/jit.py:70, in _JitWrapper.__call__(self, *args, **kwargs)
#      68         return self._fun_wrapper(False, args, kwargs)
#      69 else:
# ---> 70     return self._fun_wrapper(False, args, kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/jit.py:59, in _JitWrapper._fun_wrapper(self, is_lower, args, kwargs)
#      57     return self._cached.lower(dynamic, static)
#      58 else:
# ---> 59     dynamic_out, static_out = self._cached(dynamic, static)
#      60     return combine(dynamic_out, static_out.value)
#
#     [... skipping hidden 12 frame]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/jit.py:30, in _filter_jit_cache.<locals>.fun_wrapped(dynamic, static)
#      28 fun = hashable_combine(dynamic_fun, static_fun)
#      29 args, kwargs = hashable_combine(dynamic_spec, static_spec)
# ---> 30 out = fun(*args, **kwargs)
#      31 dynamic_out, static_out = partition(out, is_array)
#      32 return dynamic_out, Static(static_out)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/integrate.py:752, in diffeqsolve(terms, solver, t0, t1, dt0, y0, args, saveat, stepsize_controller, adjoint, discrete_terminating_event, max_steps, throw, solver_state, controller_state, made_jump)
#     731 init_state = State(
#     732     y=y0,
#     733     tprev=tprev,
#    (...)
#     745     dense_save_index=dense_save_index,
#     746 )
#     748 #
#     749 # Main loop
#     750 #
# --> 752 final_state, aux_stats = adjoint.loop(
#     753     args=args,
#     754     terms=terms,
#     755     solver=solver,
#     756     stepsize_controller=stepsize_controller,
#     757     discrete_terminating_event=discrete_terminating_event,
#     758     saveat=saveat,
#     759     t0=t0,
#     760     t1=t1,
#     761     dt0=dt0,
#     762     max_steps=max_steps,
#     763     init_state=init_state,
#     764     throw=throw,
#     765     passed_solver_state=passed_solver_state,
#     766     passed_controller_state=passed_controller_state,
#     767 )
#     769 #
#     770 # Finish up
#     771 #
#     773 is_save_state = lambda x: isinstance(x, SaveState)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/adjoint.py:286, in RecursiveCheckpointAdjoint.loop(***failed resolving arguments***)
#     282     outer_while_loop = ft.partial(
#     283         _outer_loop, kind="checkpointed", checkpoints=self.checkpoints
#     284     )
#     285     msg = None
# --> 286 final_state = self._loop(
#     287     terms=terms,
#     288     saveat=saveat,
#     289     init_state=init_state,
#     290     max_steps=max_steps,
#     291     inner_while_loop=inner_while_loop,
#     292     outer_while_loop=outer_while_loop,
#     293     **kwargs,
#     294 )
#     295 if msg is not None:
#     296     final_state = eqxi.nondifferentiable_backward(
#     297         final_state, msg=msg, symbolic=True
#     298     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/integrate.py:371, in loop(solver, stepsize_controller, discrete_terminating_event, saveat, t0, t1, dt0, max_steps, terms, args, init_state, inner_while_loop, outer_while_loop)
#     367         new_state = eqx.tree_at(lambda s: s.result, new_state, result)
#     369     return new_state
# --> 371 final_state = outer_while_loop(
#     372     cond_fun, body_fun, init_state, max_steps=max_steps, buffers=_outer_buffers
#     373 )
#     375 def _save_t1(subsaveat, save_state):
#     376     if subsaveat.t1 and not subsaveat.steps:
#     377         # If subsaveat.steps then the final value is already saved.
#     378         #
#     379         # Use `tprev` instead of `t1` in case of an event terminating the solve
#     380         # early. (And absent such an event then `tprev == t1`.)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/internal/while_loop/while_loop.py:85, in while_loop(***failed resolving arguments***)
#      83 elif kind == "checkpointed":
#      84     del kind, base
# ---> 85     return checkpointed_while_loop(
#      86         cond_fun,
#      87         body_fun,
#      88         init_val,
#      89         max_steps=max_steps,
#      90         buffers=buffers,
#      91         checkpoints=checkpoints,
#      92     )
#      93 elif kind == "bounded":
#      94     del kind, checkpoints
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/internal/while_loop/checkpointed.py:229, in checkpointed_while_loop(cond_fun, body_fun, init_val, max_steps, buffers, checkpoints)
#     225     return init_val
#     226 cond_fun, body_fun, init_val, buffers = common_rewrite(
#     227     cond_fun, body_fun, init_val, max_steps, buffers, readable=False
#     228 )
# --> 229 body_fun = filter_closure_convert(body_fun, init_val)
#     230 vjp_arg = (init_val, body_fun)
#     231 _, _, final_val = _checkpointed_while_loop(vjp_arg, cond_fun, checkpoints, buffers)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/ad.py:354, in filter_closure_convert(fn, *args, **kwargs)
#     350 if isinstance(fn, types.FunctionType) and fn.__closure__ is None:
#     351     # In this case, it's not possible to have any closed-over tracers.
#     352     # Skip jaxpr tracing for efficiency.
#     353     return fn
# --> 354 closed_jaxpr, out_dynamic_struct, out_static = filter_make_jaxpr(fn)(
#     355     *args, **kwargs
#     356 )
#     357 in_dynamic, in_static = partition((args, kwargs), _is_struct)
#     358 in_dynamic_struct = jax.eval_shape(lambda: in_dynamic)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/make_jaxpr.py:28, in _MakeJaxpr.__call__(self, *args, **kwargs)
#      25     _out_dynamic, _out_static = partition(_out, is_array)
#      26     return _out_dynamic, Static(_out_static)
# ---> 28 jaxpr, out_struct = jax.make_jaxpr(_fn, return_shape=True)(*dynamic_flat)
#      29 dynamic_out_struct, static_out = out_struct
#      30 static_out = static_out.value
#
#     [... skipping hidden 6 frame]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/make_jaxpr.py:24, in _MakeJaxpr.__call__.<locals>._fn(*_dynamic_flat)
#      22 _dynamic = jtu.tree_unflatten(dynamic_treedef, _dynamic_flat)
#      23 _args, _kwargs = combine(_dynamic, static)
# ---> 24 _out = self.fn(*_args, **_kwargs)
#      25 _out_dynamic, _out_static = partition(_out, is_array)
#      26 return _out_dynamic, Static(_out_static)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/equinox/internal/while_loop/common.py:146, in common_rewrite.<locals>.new_body_fun(val)
#     142 step, pred, val = val
#     143 _, _, buffer_val = tree_at(
#     144     new_buffers(None), (None, None, val), replace_fn=wrap_buffer
#     145 )
# --> 146 buffer_val2 = body_fun(buffer_val)
#     147 if not tree_equal(
#     148     jax.eval_shape(lambda: buffer_val), jax.eval_shape(lambda: buffer_val2)
#     149 ):
#     150     raise ValueError("`body_fun` must have the same input and output structure")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/integrate.py:167, in loop.<locals>.body_fun(state)
#     160 def body_fun(state):
#     161
#     162     #
#     163     # Actually do some differential equation solving! Make numerical steps, adapt
#     164     # step sizes, all that jazz.
#     165     #
# --> 167     (y, y_error, dense_info, solver_state, solver_result) = solver.step(
#     168         terms,
#     169         state.tprev,
#     170         state.tnext,
#     171         state.y,
#     172         args,
#     173         state.solver_state,
#     174         False if cannot_make_jump else state.made_jump,
#     175     )
#     177     # e.g. if someone has a sqrt(y) in the vector field, and dt0 is so large that
#     178     # we get a negative value for y, and then get a NaN vector field. (And then
#     179     # everything breaks.) See #143.
#     180     y_error = jtu.tree_map(lambda x: jnp.where(jnp.isnan(x), jnp.inf, x), y_error)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/solver/leapfrog_midpoint.py:69, in LeapfrogMidpoint.step(***failed resolving arguments***)
#      67 tm1, ym1 = solver_state
#      68 control = terms.contr(tm1, t1)
# ---> 69 y1 = (ym1**ω + terms.vf_prod(t0, y0, args, control) ** ω).ω
#      70 dense_info = dict(y0=y0, y1=y1)
#      71 solver_state = (t0, y0)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/term.py:138, in AbstractTerm.vf_prod(self, t, y, args, control)
#      94 def vf_prod(self, t: Scalar, y: PyTree, args: PyTree, control: PyTree) -> PyTree:
#      95     r"""The composition of [`diffrax.AbstractTerm.vf`][] and
#      96     [`diffrax.AbstractTerm.prod`][].
#      97
#    (...)
#     136         This function must be linear in `control`.
#     137     """
# --> 138     return self.prod(self.vf(t, y, args), control)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/term.py:364, in WrapTerm.vf(self, t, y, args)
#     362 def vf(self, t: Scalar, y: PyTree, args: PyTree) -> PyTree:
#     363     t = t * self.direction
# --> 364     return self.term.vf(t, y, args)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/term.py:345, in MultiTerm.vf(self, t, y, args)
#     344 def vf(self, t: Scalar, y: PyTree, args: PyTree) -> Tuple[PyTree, ...]:
# --> 345     return tuple(term.vf(t, y, args) for term in self.terms)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/term.py:345, in <genexpr>(.0)
#     344 def vf(self, t: Scalar, y: PyTree, args: PyTree) -> Tuple[PyTree, ...]:
# --> 345     return tuple(term.vf(t, y, args) for term in self.terms)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/diffrax/term.py:173, in ODETerm.vf(self, t, y, args)
#     172 def vf(self, t: Scalar, y: PyTree, args: PyTree) -> PyTree:
# --> 173     return self.vector_field(t, y, args)
#
#     [... skipping hidden 2 frame]
#
# /Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb Cell 3 in 8
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=83'>84</a> potential = lambda x: self.potential_func(x, np.atleast_1d(t))[0]
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=84'>85</a> grad_potential = jax.grad(potential)
# ---> <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=85'>86</a> return -grad_potential(x)
#
#     [... skipping hidden 10 frame]
#
# /Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb Cell 3 in 8
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=81'>82</a> def dvdt(self, t, x, args):
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=82'>83</a>     t = np.ones_like(x)
# ---> <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=83'>84</a>     potential = lambda x: self.potential_func(x, np.atleast_1d(t))[0]
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=84'>85</a>     grad_potential = jax.grad(potential)
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=85'>86</a>     return -grad_potential(x)
#
#     [... skipping hidden 2 frame]
#
# /Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb Cell 3 in 1
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> x = np.concatenate([x, t], axis=-1)
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> for features in self.feature_sizes[:-1]:
# ---> <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>     x = nn.Dense(features)(x)
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>     x = self.activation(x)
#      <a href='vscode-notebook-cell:/Users/smsharma/Projects/symplectic-flows/notebooks/demo.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> x = nn.Dense(self.feature_sizes[-1])(x)
#
# File <string>:12, in __init__(self, features, use_bias, dtype, param_dtype, precision, kernel_init, bias_init, parent, name)
#
#     [... skipping hidden 3 frame]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-mps/lib/python3.9/site-packages/flax/core/tracers.py:36, in check_trace_level(base_level)
#      34 level = trace_level(current_trace())
#      35 if level != base_level:
# ---> 36   raise errors.JaxTransformError()
#
# JaxTransformError: Jax transforms and Flax models cannot be mixed. (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.JaxTransformError)

# %%
# Use sample using apply
flow.apply(params, rng, method=flow.sample_single)
# Out:
# Array([-1.5419725, -1.2166172], dtype=float32)

# %%
# Use sample using apply
flow.apply(params, rng, 100, method=flow.sample)
# Out:
# Array([[ 1.3364695 , -0.29904717],
#        [-3.387125  , -1.5409858 ],
#        [-0.6493621 , -1.0735375 ],
#        ...,
#        [-1.1300862 , -1.6137078 ],
#        [ 2.4081943 ,  0.13804826],
#        [-3.0664124 , -1.4464536 ]], dtype=float32)

# %%
from sklearn import datasets, preprocessing
import matplotlib.pyplot as plt

n_samples = 10_000

x, _ = datasets.make_moons(n_samples=n_samples, noise=.06)

scaler = preprocessing.StandardScaler()
x = scaler.fit_transform(x)

plt.hist2d(x[:, 0], x[:, 1], bins=100)
plt.xlim(-2 ,2)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
opt = optax.adamw(learning_rate=6e-4, weight_decay=1e-4)
opt_state = opt.init(params)

# %%
@jax.jit
def loss_fn(params, x):
    log_prob = flow.apply(params, x)
    return -log_prob.mean()

# %%
n_steps = 2000
n_batch = 64

key = jax.random.PRNGKey(0)

with trange(n_steps) as steps:
    for step in steps:

        # Draw a random batches from x
        key, subkey = jax.random.split(key)
        idx = jax.random.choice(key, x.shape[0], shape=(n_batch,))
        
        x_batch = x[idx]
        
        loss, grads = jax.value_and_grad(loss_fn)(params, x_batch)
        updates, opt_state = opt.update(grads, opt_state, params)

        params = optax.apply_updates(params, updates)

        steps.set_postfix(val=loss)
# Out:
# 100%|██████████| 2000/2000 [04:39<00:00,  7.15it/s, val=2.2107382]

# %%
x_sample = flow.apply(params, rng, 300, method=flow.sample)

# %%
plt.hist2d(x_sample[:, 0], x_sample[:, 1], bins=100);
plt.xlim(-2 ,2)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)
